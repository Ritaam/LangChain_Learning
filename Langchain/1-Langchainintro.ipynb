# %% [markdown]
# ### Langchain version v1

# %%
import langchain
langchain.__version__
# Out:
# '1.3.1'

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.agents import create_agent

def get_weather(city: str) -> str:
    """Get the weather for a city"""
    return f"The weather in {city} is sunny."

agent = create_agent(
    model="groq:llama-3.3-70b-versatile",
    tools=[get_weather],
    system_prompt="you are a helpful assistant.",
)

# %% [markdown]
# ### Run the agent

# %%
agent.invoke({"messages": "What is the weather in Kolkata"})
# Out:
# {'messages': [HumanMessage(content='What is the weather in Kolkata', additional_kwargs={}, response_metadata={}, id='c40636d9-e1d1-40f4-875d-179cab522d0e'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'r63j23vb8', 'function': {'arguments': '{"city":"Kolkata"}', 'name': 'get_weather'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 224, 'total_tokens': 239, 'completion_time': 0.043488091, 'completion_tokens_details': None, 'prompt_time': 0.011425613, 'prompt_tokens_details': None, 'queue_time': 0.159661616, 'total_time': 0.054913704}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e4c09-eae0-7513-9b51-8abfcd33a832-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'Kolkata'}, 'id': 'r63j23vb8', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 224, 'output_tokens': 15, 'total_tokens': 239}),
#   ToolMessage(content='The weather in Kolkata is sunny.', name='get_weather', id='59dfa25f-792c-4ebb-b0fc-b8498dd89a47', tool_call_id='r63j23vb8'),
#   AIMessage(content='I am just an assistant and do not have real-time access to the weather. The actual weather in Kolkata can be obtained by using the function call as shown earlier.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 256, 'total_tokens': 290, 'completion_time': 0.170957342, 'completion_tokens_details': None, 'prompt_time': 0.013651871, 'prompt_tokens_details': None, 'queue_time': 0.056276783, 'total_time': 0.184609213}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e4c09-ecd9-7712-baaa-fa2c9c05f949-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 256, 'output_tokens': 34, 'total_tokens': 290})]}
